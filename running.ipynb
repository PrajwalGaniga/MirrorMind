# %% [markdown]
# # 1. Navigate to the root folder, then into the backend directory
# cd C:\Users\ASUS\OneDrive\Desktop\Projects\MirrorMind\backend
#
# # 2. Activate the virtual environment
# .\venv\Scripts\Activate.ps1
#
# # 3. Start the FastAPI server
# uvicorn main:app --reload

# %% [markdown]
# Terminal 2: Ngrok (Live API Tunnel)

# %% [markdown]
# # 1. Start the ngrok tunnel on port 8000
# ngrok http 8000

# %% [markdown]
# # 1. Navigate to the root folder, then into the frontend directory
# cd C:\Users\ASUS\OneDrive\Desktop\Projects\MirrorMind\frontend
#
# # 2. Start the Vite development server
# npm run dev

# %% [markdown]
# # 1. Navigate to the mobile-app directory
# cd C:\Users\ASUS\OneDrive\Desktop\Projects\MirrorMind\mobile-app
#
# # 2. Run the flutter app
# flutter run
